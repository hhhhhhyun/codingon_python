# %%
import folium
import pandas as pd
import os #파일 주소 확인
print(os.getcwd())
# Out:
# c:\codingon\python\10.데이터분석

# %%
data = pd.read_csv("택시승차대 현황.csv", encoding='cp949')
data
# Out:
#          행정구역                        위치명               도로명 주소  \
# 0   서울특별시 마포구              신용보증기금 마포지점 앞   서울특별시 마포구 마포대로 122
# 1   서울특별시 마포구                마포SK허브 빌딩 앞   서울특별시 마포구 마포대로 204
# 2   서울특별시 마포구                  트라팰리스빌딩 앞    서울특별시 마포구 마포대로 53
# 3   서울특별시 마포구    주식회사 메칸더브이 앞(혜당한방병원 건너)     서울특별시 마포구 독막로 31
# 4   서울특별시 마포구                신의주 찹쌀순대점 앞  서울특별시 마포구 서강로 18길 2
# 5   서울특별시 마포구  아이스페이스 빌딩 앞(하나은행 신촌지점 좌측)    서울특별시 마포구 서강로 133
# 6   서울특별시 마포구           동우빌딩 앞(키움참치 홍대점)     서울특별시 마포구 신촌로 12
# 7   서울특별시 마포구                홍반장감자탕전문점 앞   서울특별시 마포구 월드컵로 137
# 8   서울특별시 마포구      마포롯데캐슬 앞(공덕역 2번출구 방향)   서울특별시 마포구 마포대로 109
# 9   서울특별시 마포구                   서울가든호텔 앞    서울특별시 마포구 마포대로 58
# 10  서울특별시 마포구                 망원역 1번출구 앞    서울특별시 마포구 월드컵로 80
#
#                      지번 주소         위도          경도  데이터기준일자  Unnamed: 7
# 0      서울특별시 마포구 공덕동 254-5  37.545397  126.952564  44966.0         NaN
# 1        서울특별시 마포구 아현동 737  37.552001  126.956512  44966.0         NaN
# ...

# %%
taxi = data.loc[:, ["위치명", "위도", "경도"]]
taxi
# Out:
#                           위치명         위도          경도
# 0               신용보증기금 마포지점 앞  37.545397  126.952564
# 1                 마포SK허브 빌딩 앞  37.552001  126.956512
# 2                   트라팰리스빌딩 앞  37.541448  126.947233
# 3     주식회사 메칸더브이 앞(혜당한방병원 건너)  37.548428  126.916896
# 4                 신의주 찹쌀순대점 앞  37.553712  126.935189
# 5   아이스페이스 빌딩 앞(하나은행 신촌지점 좌측)  37.555143  126.935994
# 6            동우빌딩 앞(키움참치 홍대점)  37.558086  126.927690
# 7                 홍반장감자탕전문점 앞  37.560302  126.905950
# 8       마포롯데캐슬 앞(공덕역 2번출구 방향)  37.544281  126.950622
# 9                    서울가든호텔 앞  37.540719  126.948352
# 10                 망원역 1번출구 앞  37.556207  126.910446

# %%
for index, row in taxi.iterrows():
    folium.Marker(location = ["위치명"], popup="위치명", tooltip="",
              icon=folium.Icon(color='black', icon='fa-solid fa-heart', prefix=('fa-solid'))).add_to(m)
     m
