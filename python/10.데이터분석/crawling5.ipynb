# %%
# %pip install selenium
# Out:
# Collecting selenium
#   Downloading selenium-4.27.1-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\there\anaconda3\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (2.2.3)
# Collecting trio~=0.17 (from selenium)
#   Downloading trio-0.27.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting trio-websocket~=0.9 (from selenium)
#   Downloading trio_websocket-0.11.1-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\there\anaconda3\lib\site-packages (from selenium) (2024.8.30)
# Requirement already satisfied: typing_extensions~=4.9 in c:\users\there\anaconda3\lib\site-packages (from selenium) (4.11.0)
# Requirement already satisfied: websocket-client~=1.8 in c:\users\there\anaconda3\lib\site-packages (from selenium) (1.8.0)
# Collecting attrs>=23.2.0 (from trio~=0.17->selenium)
#   Downloading attrs-24.3.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: sortedcontainers in c:\users\there\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in c:\users\there\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.7)
# Collecting outcome (from trio~=0.17->selenium)
#   Downloading outcome-1.3.0.post0-py2.py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: sniffio>=1.3.0 in c:\users\there\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.3.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\there\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.17.1)
# Collecting wsproto>=0.14 (from trio-websocket~=0.9->selenium)
#   Downloading wsproto-1.2.0-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in c:\users\there\anaconda3\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\there\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\there\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)
# Downloading selenium-4.27.1-py3-none-any.whl (9.7 MB)
#    ---------------------------------------- 0.0/9.7 MB ? eta -:--:--
#    --------- ------------------------------ 2.4/9.7 MB 11.2 MB/s eta 0:00:01
#    ------------------- -------------------- 4.7/9.7 MB 11.9 MB/s eta 0:00:01
#    ------------------------------ --------- 7.3/9.7 MB 11.6 MB/s eta 0:00:01
#    ------------------------------------- -- 9.2/9.7 MB 11.2 MB/s eta 0:00:01
#    ---------------------------------------- 9.7/9.7 MB 10.2 MB/s eta 0:00:00
# Downloading trio-0.27.0-py3-none-any.whl (481 kB)
# Downloading trio_websocket-0.11.1-py3-none-any.whl (17 kB)
# Downloading attrs-24.3.0-py3-none-any.whl (63 kB)
# Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Downloading outcome-1.3.0.post0-py2.py3-none-any.whl (10 kB)
# Installing collected packages: wsproto, attrs, outcome, trio, trio-websocket, selenium
#   Attempting uninstall: attrs
#     Found existing installation: attrs 23.1.0
#     Uninstalling attrs-23.1.0:
#       Successfully uninstalled attrs-23.1.0
# Successfully installed attrs-24.3.0 outcome-1.3.0.post0 selenium-4.27.1 trio-0.27.0 trio-websocket-0.11.1 wsproto-1.2.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

import time

# options 객체를 만들지 않으면 실행시 브라우저 창이 꺼짐
options = Options()
options.add_argument("--start-maximized") #창크기 최대화
options.add_experimental_option('detach', True)

driver = webdriver.Chrome(options=options)  

url = "https://www.naver.com/"
driver.get(url)

# %%
# 창 열리고 3초 대기후에 검색어 입력됨
time.sleep(3)

# 검색어 입력 - id 선택자
# query = driver.find_element(By.ID, "query")
# query.send_keys("빅데이터")
driver.find_element(By.ID, "query").send_keys("빅데이터")
# 검색어 입력후 2초 대기 후 클릭됨
time.sleep(2)

# 검색 버튼 클릭
search_btn = driver.find_element(By.CSS_SELECTOR, "#search-btn")
search_btn.click()

# 엔터 쳐서 검색
# driver.find_element(By.ID, "query").send_keys(Keys.ENTER)
# time.sleep(2)

# 스크린 샷 
driver.save_screenshot("./python/10.데이터분석/crawling/스팩.png")

driver.quit()

# %%
#실습2에서 사용할 코드-> 무한 스크롤
'''
current_height = driver.execute_script("return window.scrollY")

count = 0

while True:
    driver.find_element(By.CSS_SELECTOR, 'body').send_keys(Keys.END)
    time.sleep(1)
    
    scrolled_height = driver.execute_script("return window.scrollY")
    
    if (current_height == scrolled_height):
        break
    
    if count > 1:
        break
    count+=1
    
    current_height = scrolled_height
'''
# Out:
# '\ncurrent_height = driver.execute_script("return window.scrollY")\n\ncount = 0\n\nwhile True:\n    driver.find_element(By.CSS_SELECTOR, \'body\').send_keys(Keys.END)\n    time.sleep(1)\n    \n    scrolled_height = driver.execute_script("return window.scrollY")\n    \n    if (current_height == scrolled_height):\n        break\n    \n    if count > 1:\n        break\n    count+=1\n    \n    current_height = scrolled_height\n'

# %%
# 실습2. 네이버 쇼핑 목록 가져오기
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

chrome_options = Options()
chrome_options.add_experimental_option("detach", True)

import time

driver = webdriver.Chrome(options=options)  
driver.get("https://shopping.naver.com/home")
time.sleep(2)

search = driver.find_element(By.CSS_SELECTOR, '#gnb-gnb > div._gnb_header_area_nfFfz > div > div._gnbContent_gnb_content_JUwjU > div._gnbSearch_gnb_search_ULxKx > form > div > div > div > div > input')
search.click()
search.send_keys('사과')

search_btn = driver.find_element(By.CSS_SELECTOR, '#gnb-gnb > div._gnb_header_area_nfFfz > div > div._gnbContent_gnb_content_JUwjU > div._gnbSearch_gnb_search_ULxKx > form > div > div > div > div > button._searchInput_button_search_wu9xq._nlog_click > svg')
search_btn.click()
time.sleep(2)

current_height = driver.execute_script("return window.scrollY")

count = 0

while True:
    driver.find_element(By.CSS_SELECTOR, 'body').send_keys(Keys.END)
    time.sleep(1)
    
    scrolled_height = driver.execute_script("return window.scrollY")
    
    if (current_height == scrolled_height):
        break
    
    if count > 1:
        break
    count+=1
    
    current_height = scrolled_height

import openpyxl
# 엑셀 만들기
wb = openpyxl.Workbook()

# 워크시트 만들기
ws = wb.active
ws.title = '쇼핑'

# 데이터 추가하기
ws.append(['상품명', '판매가', 'url'])

# 엑셀 저장하기
filePath = 'shopping.xlsx'

products = driver.find_elements(By.CSS_SELECTOR, '.basicProductCard_basic_product_card__TdrHT')

for product in products:
    # print("product",product)
    t = product.find_element(By.CSS_SELECTOR, '.basicProductCardInformation_title__Bc_Ng').text
    print(t)
    p = product.find_element(By.CSS_SELECTOR, '.priceTag_inner_price__TctbK').text.split()[0]    
    print(p)
    a = product.find_element(By.CSS_SELECTOR, '.basicProductCard_link__urzND')
    # print(a)
    l = a.get_attribute("href")
    print(l)
    ws.append([t, p, l])

wb.save(filePath)

#코드 스탭별로 나눠서 다시 작성해보기
# Out:
# 경북 부사사과 고당도 못난이사과 꿀 시나노골드
# 19,900
# https://adcr.naver.com/adcr?x=yzD1demTidOr2rgL6jf+RP///w==...#channelProductNo=11067488798
# 월드마켓 아삭하고 달콤한 정품 엔비사과 3kg, 5kg, 10kg
# 28,900
# https://adcr.naver.com/adcr?x=1EhRGBwdyA7F9mzLcBLUu////w==...#channelProductNo=5197349492
# 경북사과 영주부사 3kg 3키로 고당도 꿀부사 못난이흠과
# 39,000
# https://adcr.naver.com/adcr?x=Mo0ri47URBUqunuKtJg8i////w==...#channelProductNo=11260710008
# 경북 영주 제철 가정용부사 3kg 3키로 못난이꿀사과 농가직판 맛있는 사과추천
# 39,000
# https://adcr.naver.com/adcr?x=JntzfYacIQtvRbsJpXsRTP///w==...#channelProductNo=11260707405
# 사과 청송 경북 부사 못난이 가정용 선물용 2kg 5kg 10kg
# 36,900
# https://smartstore.naver.com/main/products/10793566737?nl-query=%EC%82%AC%EA%B3%BC&nl-au=e0007faeb12f4992be5f3e3760110593&NaPm=ci%3De0007faeb12f4992be5f3e3760110593%7Cct%3Dm4xlazsi%7Ctr%3Dnslsl%7Csn%3D11223024%7Chk%3D6d37d3618d7efb86add181464b770703c346f975
# 영주 풍기 부사 부석사과 선물세트 5kg 10kg
# 25,000
# https://smartstore.naver.com/main/products/11116631999?nl-query=%EC%82%AC%EA%B3%BC&nl-au=524c5e3d7e7943488c46aaeb2272d3d5&NaPm=ci%3D524c5e3d7e7943488c46aaeb2272d3d5%7Cct%3Dm4xlb1g5%7Ctr%3Dnslsl%7Csn%3D11766144%7Chk%3D01f3acc954f7f01270e07856768e4c37e2157af3
# 해플스사과, 믿고먹는 2.5kg 5kg 10kg 햇사과 맛있는사과 거창사과 하냥농부
# 53,000
# https://smartstore.naver.com/main/products/2446833831?nl-query=%EC%82%AC%EA%B3%BC&nl-au=2494750101b94abd8aab054e6c3c5bc8&NaPm=ci%3D2494750101b94abd8aab054e6c3c5bc8%7Cct%3Dm4xlb1g5%7Ctr%3Dnslsl%7Csn%3D622873%7Chk%3D02091b27f699bed28fbaa0ab1efc090a18a17aa1
# 영동 햇 꿀 사과 껍질째먹는 맛있는 햇 부사 명절 사과선물세트
# 32,980
# https://smartstore.naver.com/main/products/5032110846?nl-query=%EC%82%AC%EA%B3%BC&nl-au=d765dbb6417943e8a7e52887a4cccd1f&NaPm=ci%3Dd765dbb6417943e8a7e52887a4cccd1f%7Cct%3Dm4xlb1g5%7Ctr%3Dnslsl%7Csn%3D854334%7Chk%3D49586960396d21943a346b5b2b19f56cb2844714
# 경북사과 햇부사 햇사과 못난이 미니과일 낱개포장 세척사과 코스트코 흠과 소과 기스 꿀사과
# 9,900
# https://smartstore.naver.com/main/products/8277899953?nl-query=%EC%82%AC%EA%B3%BC&nl-au=5ab746112afc4872a115ec5e68cc1606&NaPm=ci%3D5ab746112afc4872a115ec5e68cc1606%7Cct%3Dm4xlb1g5%7Ctr%3Dnslsl%7Csn%3D455406%7Chk%3D86c48f8da6b8579713cf579cb4fb2345f8763182

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

chrome_options = Options()
chrome_options.add_experimental_option("detach", True)

import time

driver = webdriver.Chrome(options=options)  
driver.get("https://shopping.naver.com/home")
time.sleep(2)

# %%
search = driver.find_element(By.CSS_SELECTOR, '#gnb-gnb > div._gnb_header_area_nfFfz > div > div._gnbContent_gnb_content_JUwjU > div._gnbSearch_gnb_search_ULxKx > form > div > div > div > div > input')
search.click()
search.send_keys('사과')

search_btn = driver.find_element(By.CSS_SELECTOR, '#gnb-gnb > div._gnb_header_area_nfFfz > div > div._gnbContent_gnb_content_JUwjU > div._gnbSearch_gnb_search_ULxKx > form > div > div > div > div > button._searchInput_button_search_wu9xq._nlog_click > svg')
search_btn.click()
time.sleep(2)

# %%
current_height = driver.execute_script("return window.scrollY")

count = 0

while True:
    driver.find_element(By.CSS_SELECTOR, 'body').send_keys(Keys.END)
    time.sleep(1)
    
    scrolled_height = driver.execute_script("return window.scrollY")
    
    if (current_height == scrolled_height):
        break
    
    if count > 1:
        break
    count+=1
    
    current_height = scrolled_height

import openpyxl
